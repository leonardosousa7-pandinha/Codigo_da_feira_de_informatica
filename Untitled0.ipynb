# %% [markdown]
# Instalando o SDK do Google

# %%
# !pip install -q -U google-generativeai

# %%
# Import the Python SDK
import google.generativeai as genai

GOOGLE_API_KEY = "AIzaSyCr_ACca9b68qEOHxFKj5Q8jGLR0IYoAHo"
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# Listar os modelos disponíveis

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# ...

# %%
generation_config = {
    "candidate_count" : 1,
    "temperature" : 0.5
}

# %%
safety_settings = {
    "HARASSMENT" : "BLOCK_NONE",
    "HATE" : "BLOCK_NONE",
    "SEXUAL" : "BLOCK_NONE",
    "DANGEROUS" : "BLOCK_NONE",
    }

# %%
model = genai.GenerativeModel(model_name="gemini-2.5-flash-preview-05-20",
generation_config=generation_config,
                              safety_settings=safety_settings)

# %%
response = model.generate_content("Quem descobriu o Brasil?")
print(response.text)
# Out:
# O Brasil foi oficialmente descoberto por **Pedro Álvares Cabral**.
#
# Isso aconteceu em **22 de abril de 1500**.
#
# Ele era um navegador português que liderava uma expedição com destino às Índias, mas acabou chegando ao litoral do que hoje é o Brasil.
#
# É importante ressaltar que, quando os portugueses chegaram, o território já era habitado por diversos povos indígenas, que eram os verdadeiros habitantes originais da terra. Portanto, a "descoberta" se refere à chegada dos europeus e ao início da colonização portuguesa.

# %%
response = model.generate_content("Quem descobriu o Brasil?")
print(response.text)
# Out:
# O Brasil foi "descoberto" por **Pedro Álvares Cabral**, um navegador português, em **22 de abril de 1500**.
#
# No entanto, é fundamental ressaltar que o termo "descoberta" se refere à chegada dos europeus. O território já era habitado por diversos povos indígenas há milhares de anos antes da chegada de Cabral e sua frota.

# %%
chat = model.start_chat(history=[])

# %%
prompt = input("Esperando o seu comando: ")
while prompt != "fim":
  response = chat.send_message(prompt)
  print("Resposta: ", response.text, "\n")
  prompt = input("Esperando o seu comando: ")
# Out:
# Esperando o seu comando: fim

# %%
chat.history
# Out:
# []

# %%
#Melhorando a visualização
import textwrap
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('.', '')
